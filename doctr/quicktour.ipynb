# %% [markdown]
# Looking for some examples on how to use docTR for OCR-related tasks? You've come to the right place 😀

# %% [markdown]
# # Installation
#
# Install all the dependencies to make the most out of docTR. The project provides two main [installation](https://mindee.github.io/doctr/latest/installing.html) streams: one for stable release, and developer mode.

# %% [markdown]
# ## Latest stable release
#
# This will install the last stable release that was published by our teams on pypi. It is expected to provide a clean and non-buggy experience for all users.

# %%
# TensorFlow
# !pip install python-doctr[tf,viz]

# PyTorch
# First we have to uninstall the preinstalled tensorflow version if we want to work with PyTorch as backend
# because the env variables USE_TORCH=1 / USE_TF=1 doesn't have an effect in Colab
# !pip uninstall -y tensorflow
# !pip install python-doctr[torch,viz]
# Out:
# Found existing installation: tensorflow 2.18.0
# Uninstalling tensorflow-2.18.0:
#   Successfully uninstalled tensorflow-2.18.0
# Collecting python-doctr[torch,viz]
#   Downloading python_doctr-0.12.0-py3-none-any.whl.metadata (34 kB)
# Requirement already satisfied: numpy<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (2.0.2)
# Requirement already satisfied: scipy<2.0.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (1.15.3)
# Requirement already satisfied: h5py<4.0.0,>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (3.14.0)
# Requirement already satisfied: opencv-python<5.0.0,>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (4.11.0.86)
# Collecting pypdfium2<5.0.0,>=4.11.0 (from python-doctr[torch,viz])
#   Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (48 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 2.3 MB/s eta 0:00:00
# Collecting pyclipper<2.0.0,>=1.2.0 (from python-doctr[torch,viz])
#   Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.0 kB)
# Requirement already satisfied: shapely<3.0.0,>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (2.1.1)
# Collecting langdetect<2.0.0,>=1.0.9 (from python-doctr[torch,viz])
#   Downloading langdetect-1.0.9.tar.gz (981 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 20.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting rapidfuzz<4.0.0,>=3.0.0 (from python-doctr[torch,viz])
#   Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (0.33.1)
# Requirement already satisfied: Pillow>=9.2.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (11.2.1)
# Requirement already satisfied: defusedxml>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (0.7.1)
# Collecting anyascii>=0.3.2 (from python-doctr[torch,viz])
#   Downloading anyascii-0.3.3-py3-none-any.whl.metadata (1.6 kB)
# Collecting validators>=0.18.0 (from python-doctr[torch,viz])
#   Downloading validators-0.35.0-py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: tqdm>=4.30.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (4.67.1)
# Requirement already satisfied: torch<3.0.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (2.6.0+cu124)
# Requirement already satisfied: torchvision>=0.15.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (0.21.0+cu124)
# Collecting onnx<3.0.0,>=1.12.0 (from python-doctr[torch,viz])
#   Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: matplotlib>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from python-doctr[torch,viz]) (3.10.0)
# Collecting mplcursors>=0.3 (from python-doctr[torch,viz])
#   Downloading mplcursors-0.6-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (3.18.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2025.3.2)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (6.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (1.1.5)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from langdetect<2.0.0,>=1.0.9->python-doctr[torch,viz]) (1.17.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.0->python-doctr[torch,viz]) (2.9.0.post0)
# Requirement already satisfied: protobuf>=4.25.1 in /usr/local/lib/python3.11/dist-packages (from onnx<3.0.0,>=1.12.0->python-doctr[torch,viz]) (5.29.5)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz])
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0.0,>=2.0.0->python-doctr[torch,viz]) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub<1.0.0,>=0.20.0->python-doctr[torch,viz]) (2025.6.15)
# Downloading anyascii-0.3.3-py3-none-any.whl (345 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.1/345.1 kB 21.2 MB/s eta 0:00:00
# Downloading mplcursors-0.6-py3-none-any.whl (20 kB)
# Downloading onnx-1.18.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 63.5 MB/s eta 0:00:00
# Downloading pyclipper-1.3.0.post6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (969 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 969.6/969.6 kB 36.2 MB/s eta 0:00:00
# Downloading pypdfium2-4.30.1-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 52.1 MB/s eta 0:00:00
# Downloading rapidfuzz-3.13.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 75.4 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 77.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 65.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.7 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.5 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 74.2 MB/s eta 0:00:00
# Downloading validators-0.35.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.7/44.7 kB 2.6 MB/s eta 0:00:00
# Downloading python_doctr-0.12.0-py3-none-any.whl (377 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 377.2/377.2 kB 21.9 MB/s eta 0:00:00
# Building wheels for collected packages: langdetect
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993223 sha256=654a04c207505b6546004379faa3f93e348553ffab9d8cbd70ede70948b38958
#   Stored in directory: /root/.cache/pip/wheels/0a/f2/b2/e5ca405801e05eb7c8ed5b3b4bcf1fcabcd6272c167640072e
# Successfully built langdetect
# Installing collected packages: pyclipper, validators, rapidfuzz, pypdfium2, onnx, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, langdetect, anyascii, nvidia-cusparse-cu12, nvidia-cudnn-cu12, python-doctr, nvidia-cusolver-cu12, mplcursors
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed anyascii-0.3.3 langdetect-1.0.9 mplcursors-0.6 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 onnx-1.18.0 pyclipper-1.3.0.post6 pypdfium2-4.30.1 python-doctr-0.12.0 rapidfuzz-3.13.0 validators-0.35.0

# %% [markdown]
# ## From source
#
# Before being staged for a stable release, we constantly iterate on the community feedback to improve the library. Bug fixes and performance improvements are regularly pushed to the project Git repository. Using this installation method, you will access all the latest features that have not yet made their way to a pypi release!

# %%
# Install the most up-to-date version from GitHub

# TensorFlow
# !pip install python-doctr[tf,viz]@git+https://github.com/mindee/doctr.git

# PyTorch
# First we have to uninstall the preinstalled tensorflow version if we want to work with PyTorch as backend
# because the env variables USE_TORCH=1 / USE_TF=1 doesn't have an effect in Colab
# !pip uninstall -y tensorflow
# !pip install python-doctr[torch,viz]@git+https://github.com/mindee/doctr.git

# %% [markdown]
# # Basic usage
#
# We're going to review the main features of docTR 🎁
# And for you to have a proper overview of its capabilities, we will need some free fonts for a proper output visualization:

# %%
# Install some free fonts for result rendering
# !sudo apt-get install fonts-freefont-ttf -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   fonts-freefont-ttf
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 2,388 kB of archives.
# After this operation, 6,653 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/main amd64 fonts-freefont-ttf all 20120503-10build1 [2,388 kB]
# Fetched 2,388 kB in 0s (5,249 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package fonts-freefont-ttf.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../fonts-freefont-ttf_20120503-10build1_all.deb ...
# Unpacking fonts-freefont-ttf (20120503-10build1) ...
# Setting up fonts-freefont-ttf (20120503-10build1) ...
# Processing triggers for fontconfig (2.13.1-4.2ubuntu5) ...

# %% [markdown]
# Let's take care of all the imports directly

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

from doctr.io import DocumentFile
from doctr.models import ocr_predictor

# %% [markdown]
# For the next steps, we will need a proper PDF document that will be used to showcase the library features

# %%
# Download a sample
# !wget https://www.abacus-conseil.fr/wp-content/uploads/2023/06/exemple-paie-cadre-simple-2025.pdf
# Read the file
doc = DocumentFile.from_pdf("exemple-paie-cadre-simple-2025.pdf")
print(f"Number of pages: {len(doc)}")
# Out:
# --2025-07-04 19:41:24--  https://www.abacus-conseil.fr/wp-content/uploads/2023/06/exemple-paie-cadre-simple-2025.pdf
# Resolving www.abacus-conseil.fr (www.abacus-conseil.fr)... 91.234.194.113, 2a00:7ee0:9:3:44:1:0:260
# Connecting to www.abacus-conseil.fr (www.abacus-conseil.fr)|91.234.194.113|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72761 (71K) [application/pdf]
# Saving to: ‘exemple-paie-cadre-simple-2025.pdf’
#
# exemple-paie-cadre- 100%[===================>]  71.06K  --.-KB/s    in 0.1s
#
# 2025-07-04 19:41:25 (685 KB/s) - ‘exemple-paie-cadre-simple-2025.pdf’ saved [72761/72761]
#
# Number of pages: 1

# %% [markdown]
# docTR is, under the hood, running Deep Learning models to perform the different tasks it supports. Those models were built and trained with very popular frameworks for maximum compatibility (you will be pleased to know that you can switch from [PyTorch](https://pytorch.org/) to [TensorFlow](https://www.tensorflow.org/) without noticing any difference for you). By default, our high-level API sets the best default values so that you get high performing models without having to know anything about it. All of this is wrapper in a `Predictor` object, which will take care of pre-processing, model inference and post-processing for you ⚡
#
# Let's instantiate one!

# %%
# Instantiate a pretrained model
predictor = ocr_predictor(pretrained=True)

# %% [markdown]
# By default, PyTorch model provides a nice visual description of a model, which is handy when it comes to debugging or knowing what you just created. We also added a similar feature for TensorFlow backend so that you don't miss on this nice assistance.
#
# Let's dive into this model 🕵

# %%
# Display the architecture
print(predictor)
# Out:
# OCRPredictor(
#   (det_predictor): DetectionPredictor(
#     (pre_processor): PreProcessor(
#       (resize): Resize(output_size=(1024, 1024), interpolation='bilinear', preserve_aspect_ratio=True, symmetric_pad=True)
#       (normalize): Normalize(mean=(0.798, 0.785, 0.772), std=(0.264, 0.2749, 0.287))
#     )
#     (model): FAST()
#   )
#   (reco_predictor): RecognitionPredictor(
#     (pre_processor): PreProcessor(
#       (resize): Resize(output_size=(32, 128), interpolation='bilinear', preserve_aspect_ratio=True, symmetric_pad=False)
#       (normalize): Normalize(mean=(0.694, 0.695, 0.693), std=(0.299, 0.296, 0.301))
#     )
#     (model): CRNN(
#       (feat_extractor): Sequential(
#         (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (2): ReLU(inplace=True)
#         (3): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (4): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (5): ReLU(inplace=True)
#         (6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (7): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (8): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (9): ReLU(inplace=True)
#         (10): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (11): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (12): ReLU(inplace=True)
#         (13): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#         (14): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (15): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (16): ReLU(inplace=True)
#         (17): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (18): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (19): ReLU(inplace=True)
#         (20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (21): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (22): ReLU(inplace=True)
#         (23): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (24): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (25): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (26): ReLU(inplace=True)
#         (27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (28): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (29): ReLU(inplace=True)
#         (30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (31): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (32): ReLU(inplace=True)
#         (33): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#         (34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (35): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (36): ReLU(inplace=True)
#         (37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (38): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (39): ReLU(inplace=True)
#         (40): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (41): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (42): ReLU(inplace=True)
#         (43): MaxPool2d(kernel_size=(2, 1), stride=(2, 1), padding=0, dilation=1, ceil_mode=False)
#       )
#       (decoder): LSTM(512, 128, num_layers=2, batch_first=True, bidirectional=True)
#       (linear): Linear(in_features=256, out_features=124, bias=True)
#       (postprocessor): CTCPostProcessor(vocab_size=123)
#     )
#   )
# )

# %% [markdown]
# Here we are inspecting the most complex (and high-level) object of docTR API: an OCR predictor. Since docTR achieves Optical Character Recognition by first localizing textual elements (Text Detection), then extracting the corresponding text from each location (Text Recognition), the OCR Predictor wraps two sub-predictors: one for text detection, and the other for text recognition.

# %% [markdown]
# ## Basic inference
#
# It looks quite complex, isn't it?
# Well that will not prevent you from easily get nice results. See for yourself:

# %%
result = predictor(doc)

# %% [markdown]
# ## Prediction visualization
#
# If you rightfully prefer to see the results with your eyes, docTR includes a few visualization features. We will first overlay our predictions on the original document:

# %%
result.show()

# %% [markdown]
# Looks accurate!
# But we can go further: if the extracted information is correctly structured, we should be able to recreate the page entirely. So let's do this 🎨

# %%
synthetic_pages = result.synthesize()
plt.imshow(synthetic_pages[0]); plt.axis('off'); plt.show()

# %% [markdown]
# ## Exporting results
#
# OK, so the predictions are relevant, but how would you integrate this into your own document processing pipeline? Perhaps you're not using Python at all?
#
# Well, if you happen to be using JSON or XML exports, they are already supported 🤗

# %%
# JSON export
json_export = result.export()
print(json_export)
# Out:
# {'pages': [{'page_idx': 0, 'dimensions': (1685, 1190), 'orientation': {'value': None, 'confidence': None}, 'language': {'value': None, 'confidence': None}, 'blocks': [{'geometry': ((np.float64(0.03953436843487396), np.float64(0.005859375)), (np.float64(0.9494033941701681), np.float64(1.0))), 'objectness_score': 0.7455539296699476, 'lines': [{'geometry': ((np.float64(0.1446256236869748), np.float64(0.005859375)), (np.float64(0.9452550551470589), np.float64(0.02734375))), 'objectness_score': 0.7972266588892255, 'words': [{'value': 'BULLETIN', 'confidence': 0.9967143535614014, 'geometry': ((np.float64(0.1446256236869748), np.float64(0.0087890625)), (np.float64(0.29120026917016806), np.float64(0.0224609375))), 'objectness_score': 0.8623031377792358, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'DE', 'confidence': 0.9997593760490417, 'geometry': ((np.float64(0.3036452862394958), np.float64(0.0078125)), (np.float64(0.3451286764705882), np.float64(0.0244140625))), 'objectness_score': 0.7797713279724121, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'PAIE', 'confidence': 0.9998206496238708, 'geometry': ((np.float64(0.35204257484243695), np.float64(0.0068359375)), (np.float64(0.4280954569327731), np.float64(0.0244140625))), 'objectness_score': 0.8340610861778259, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'du', 'confidence': 0.9998855590820312, 'geometry': ((np.float64(0.43224379595588236), np.float64(0.005859375)), (np.float64(0.4737271861869748), np.float64(0.025390625))), 'objectness_score': 0.8453803062438965, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': '01/01/2025', 'confidence': 0.9080661535263062, 'geometry': ((np.float64(0.4917033219537815), np.float64(0.0078125)), (np.float64(0.6797613576680672), np.float64(0.025390625))), 'objectness_score': 0.8053797483444214, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'au', 'confidence': 0.9998369216918945, 'geometry': ((np.float64(0.6977374934348739), np.float64(0.009765625)), (np.float64(0.7378381039915967), np.float64(0.025390625))), 'objectness_score': 0.7209898829460144, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': '31/01/2025', 'confidence': 0.8388948440551758, 'geometry': ((np.float64(0.7544314600840336), np.float64(0.0068359375)), (np.float64(0.9452550551470589), np.float64(0.02734375))), 'objectness_score': 0.7327011227607727, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.04506548713235292), np.float64(0.046875)), (np.float64(0.1736639968487395), np.float64(0.060546875))), 'objectness_score': 0.7375227510929108, 'words': [{'value': 'ABACUS', 'confidence': 0.9972602128982544, 'geometry': ((np.float64(0.04506548713235292), np.float64(0.048828125)), (np.float64(0.10452501313025209), np.float64(0.05859375))), 'objectness_score': 0.811965823173523, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'CONSEIL', 'confidence': 0.9980301260948181, 'geometry': ((np.float64(0.10452501313025209), np.float64(0.046875)), (np.float64(0.1736639968487395), np.float64(0.060546875))), 'objectness_score': 0.6630796790122986, 'crop_orientation': {'value': 0, 'confidence': None}}]}, {'geometry': ((np.float64(0.37140149028361347), np.float64(0.0458984375)), (np.float64(0.5359522715336135), np.float64(0.0595703125))), 'objectness_score': 0.7785879572232565, 'words': [{'value': 'Date', 'confidence': 0.9996187686920166, 'geometry': ((np.float64(0.37140149028361347), np.float64(0.0478515625)), (np.float64(0.40320542279411764), np.float64(0.05859375))), 'objectness_score': 0.7298517227172852, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': 'entrée', 'confidence': 0.9981776475906372, 'geometry': ((np.float64(0.4018226431197479), np.float64(0.0458984375)), (np.float64(0.4474543723739496), np.float64(0.0595703125))), 'objectness_score': 0.7926361560821533, 'crop_orientation': {'value': 0, 'confidence': None}}, {'value': '0 ...

# %%
# XML export
xml_output = result.export_as_xml()
print(xml_output[0][0])
# Out:
# b'<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en"><head><title>docTR - XML export (hOCR)</title><meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta name="ocr-system" content="python-doctr v0.12.0" /><meta name="ocr-capabilities" content="ocr_page ocr_carea ocr_par ocr_line ocrx_word" /></head><body><div class="ocr_page" id="page_1" title="image; bbox 0 0 1190 1685; ppageno 0"><div class="ocr_carea" id="block_1" title="bbox 47 10                     1130 1685"><p class="ocr_par" id="par_1" title="bbox 47 10                     1130 1685"><span class="ocr_line" id="line_1" title="bbox 172 10                         1125 46;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_1" title="bbox 172 15                             347 38;                             x_wconf 100">BULLETIN</span><span class="ocrx_word" id="word_2" title="bbox 361 13                             411 41;                             x_wconf 100">DE</span><span class="ocrx_word" id="word_3" title="bbox 419 12                             509 41;                             x_wconf 100">PAIE</span><span class="ocrx_word" id="word_4" title="bbox 514 10                             564 43;                             x_wconf 100">du</span><span class="ocrx_word" id="word_5" title="bbox 585 13                             809 43;                             x_wconf 91">01/01/2025</span><span class="ocrx_word" id="word_6" title="bbox 830 16                             878 43;                             x_wconf 100">au</span><span class="ocrx_word" id="word_7" title="bbox 898 12                             1125 46;                             x_wconf 84">31/01/2025</span></span><span class="ocr_line" id="line_2" title="bbox 54 79                         207 102;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_8" title="bbox 54 82                             124 99;                             x_wconf 100">ABACUS</span><span class="ocrx_word" id="word_9" title="bbox 124 79                             207 102;                             x_wconf 100">CONSEIL</span></span><span class="ocr_line" id="line_3" title="bbox 442 77                         638 100;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_10" title="bbox 442 81                             480 99;                             x_wconf 100">Date</span><span class="ocrx_word" id="word_11" title="bbox 478 77                             532 100;                             x_wconf 100">entr\xc3\xa9e</span><span class="ocrx_word" id="word_12" title="bbox 547 79                             638 100;                             x_wconf 100">01/01/2025</span></span><span class="ocr_line" id="line_4" title="bbox 784 79                         857 100;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_13" title="bbox 784 79                             857 100;                             x_wconf 87">Matricule</span></span><span class="ocr_line" id="line_5" title="bbox 916 79                         939 99;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_14" title="bbox 916 79                             939 99;                             x_wconf 100">16</span></span><span class="ocr_line" id="line_6" title="bbox 52 107                         185 130;                         baseline 0 0; x_size 0; x_descenders 0; x_ascenders 0"><span class="ocrx_word" id="word_15" title="bbox 52 107                             70 130;                             x_wconf 72">1</span><span class="ocrx_word" id="word_16" title="bbox 72 110                             103 128;                             x_wconf 100">rue</span><span class="ocrx_word" id="word_17" title="bbox 98 109                 ...

# %% [markdown]
# Or if you only need the extracted plain text

# %%
string_result = result.render()
print(string_result)
# Out:
# BULLETIN DE PAIE du 01/01/2025 au 31/01/2025
# ABACUS CONSEIL
# Date entrée 01/01/2025
# Matricule
# 16
# 1 rue de l'arrivée
# No INSEE
# Section
# 75001 PARIS
# Emploi
# CADRE
# Catégorie
# Hiérarchie
# Siret / APE 12345678900011 9999Z
# Org. Soc. URSSAF D'ILE DE FRANCE
# 93518 MONTREUIL
# Mr CADRE STANDARD
# 1 rue de l'arrivée
# NoOrg. Soc.
# 69001 LYON
# Convention Collective
# Congés Payés : Art L.3141-3 à L.3141-11 L.3141-
# 19 Préavis : Art L.1234-1 L.1237-1 L.1237-6
# L.1237-10
# ELEMENTS DE PAIE
# NOMBRE TAUX
# GAINS
# RETENUES COTISATIONS
# ou BASE
# PATRONALES
# SALAIRE DE BASE
# 151,67 30,00
# 4 550,10
# TOTAL BRUT
# 4! 550,10
# SANTÉ
# Sécurité sociale-Maladie Maternité Invalidité Décès
# 4 550,10
# 591,52
# Complémentaire! Incapacité Invalidité Décès TA
# 3 925,00
# 117,76
# Complémentaire: santé
# 26,50
# 26,50
# ACCIDENTS DU TRAVAIL-MALADIES PROFESSIONNELLES
# 4 550,10
# 34,13
# RETRAITE
# Sécurité sociale plafonnée
# 3 925,00 6,90
# 270,83
# 335,59
# Sécurité sociale déplafonnée
# 4 550,10 0,40
# 18,20
# 91,91
# Complémentaire Tranche 1
# 3 925,00 4,15
# 162,90
# 244,13
# Complémentaire Tranche 2
# 625,10 9,86
# 61,64
# 92,39
# FAMILLE
# 4 550,10
# 156,98
# ASSURANCE CHÔMAGE
# Chômage
# 4 550,10
# 195,66
# Apec
# 1,09
# 1,64
# AUTRES CONTRIBUTIONS DUES PAR L'EMPLOYEUR
# 74,29
# CSG DÉDUCTIBLE DE L'IMPÔT SUR LE REVENU
# 4 614,73 6,80
# 313,80
# CSG/CRDS NON DÉDUCTIBLE DE L'IMPÔT SUR LE REVENU
# 4 614,73 2,90
# 133,82
# TOTALI DES COTISATIONS ET CONTRIBUTIONS
# 988,78
# 1 962,50
# NET IMPOSABLE
# 3 721,64
# MONTANT NET SOCIAL
# 3 561,32
# NET À PAYER AVANT IMPÔT SUR LE REVENU
# 3 561,32
# Impôt sur le revenu
# Base
# Taux
# Montant
# Cumul annuel
# Impôt sur le revenu prélevé à la source
# 3 721,64 11,90 %
# 442,88
# 442,88
# Montant net des heures complémentaires / supplémentaires exonérées
# 0,00
# Net à payer au salarié
# 3 118,44 Eur
# Réglé le : 31/01/2025
# Solde des congés payés
# Acquis Pris Solde
# Congés de l'année
# Congés en cours d'acquisition 2,50
# 2,50 Total versé par l'employeur
# 6! 512,60 Eur
# Brut
# Net Imposable
# Charges Salariales
# Coût Entreprise
# Heures Indemnisées Heures Travaillées
# Mois : 45 550,10 Eur Mois
# 3721,64 Eur Mois:
# 988,78 Eur Mois
# 65 512,60 Eur Mois
# 151,67 Mois:
# 151,67
# Année 45 550,10 Eur Année 3721,64 Eur Année
# 988,78 Eur Année 65 512,60 Eur Année
# 151,67 Année
# 151,67
# Commentaire
# Absence(s)
# Pour la définition des termes employés, se reporter au site internet service-public.fri rubrique cotisations sociales.
# Pour toute information sur le mode de calcul du montant net social, se reportera au site internet mesdroitssociaux.gouwv.fr. Page 1 I 1
# Dans votre intérêt et pour vous aider à faire valoir vos droits, conservez ce bulletin de paie sans limitation de durée.
